# %% [markdown]
# <a href="https://colab.research.google.com/github/fpiedra47/sql_intro/blob/main/sql.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importa las librerias necesarias
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
df = pd.read_csv("/content/drive/My Drive/CodingDojo/Codigos/week12/nba.csv")
df.head()
# Out:
#               Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA   3P%  ...  \
# 0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  25.0  ...
# 1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  23.5  ...
# 2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  24.4  ...
# 3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  22.6  ...
# 4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1   0.0  ...
#
#    FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3          0.0
# 1  3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6          0.0
# 2  1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0          0.0
# 3  1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0          1.0
# 4  1.9  67.4   1.0   1.5  2.5  0.3  0.3  0.4  0.8          1.0
#
# [5 rows x 21 columns]

# %%
engine = create_engine("sqlite:///df.db", echo = True)
conn   = engine.connect()

# %%
sqlite_table = "nba_details"
df.to_sql(sqlite_table, conn)
# Out:
# 2022-03-27 14:44:40,442 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("nba_details")
# 2022-03-27 14:44:40,448 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-03-27 14:44:40,454 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("nba_details")
# 2022-03-27 14:44:40,459 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2022-03-27 14:44:40,480 INFO sqlalchemy.engine.Engine
# CREATE TABLE nba_details (
# 	"index" BIGINT,
# 	"Name" TEXT,
# 	"GP" BIGINT,
# 	"MIN" FLOAT,
# 	"PTS" FLOAT,
# 	"FGM" FLOAT,
# 	"FGA" FLOAT,
# 	"FG%" FLOAT,
# 	"3P Made" FLOAT,
# 	"3PA" FLOAT,
# 	"3P%" FLOAT,
# 	"FTM" FLOAT,
# 	"FTA" FLOAT,
# 	"FT%" FLOAT,
# 	"OREB" FLOAT,
# 	"DREB" FLOAT,
# 	"REB" FLOAT,
# 	"AST" FLOAT,
# 	"STL" FLOAT,
# 	"BLK" FLOAT,
# 	"TOV" FLOAT,
# 	"TARGET_5Yrs" FLOAT
# )
#
#
# 2022-03-27 14:44:40,486 INFO sqlalchemy.engine.Engine [no key 0.00614s] ()
# 2022-03-27 14:44:40,502 INFO sqlalchemy.engine.Engine COMMIT
# ...

# %%
sql = """
select * 
from nba_details"""

df_sql = pd.read_sql_query (sql,engine)
df_sql.head()
# Out:
# 2022-03-27 14:49:19,921 INFO sqlalchemy.engine.Engine
# select *
# from nba_details
# 2022-03-27 14:49:19,923 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index             Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA  ...  \
# 0      0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  ...
# 1      1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  ...
# 2      2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  ...
# 3      3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  ...
# 4      4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1  ...
#
#    FTA   FT%  OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs
# 0  2.3  69.9   0.7   3.4  4.1  1.9  0.4  0.4  1.3          0.0
# 1  3.4  76.5   0.5   2.0  2.4  3.7  1.1  0.5  1.6          0.0
# 2  1.3  67.0   0.5   1.7  2.2  1.0  0.5  0.3  1.0          0.0
# 3  1.3  68.9   1.0   0.9  1.9  0.8  0.6  0.1  1.0          1.0
# ...

# %%
sql = """
select Name, FGA, 1 as auxiliar
from nba_details"""

df_sql = pd.read_sql_query (sql,engine)
df_sql.head()
# Out:
# 2022-03-27 14:49:23,377 INFO sqlalchemy.engine.Engine
# select Name, FGA, 1 as auxiliar
# from nba_details
# 2022-03-27 14:49:23,379 INFO sqlalchemy.engine.Engine [raw sql] ()
#               Name  FGA  auxiliar
# 0   Brandon Ingram  7.6         1
# 1  Andrew Harrison  6.7         1
# 2   JaKarr Sampson  4.7         1
# 3      Malik Sealy  5.5         1
# 4      Matt Geiger  3.0         1

# %%
sql = """
select Name, avg(GP) as media
from nba_details
group by name
"""

df_sql = pd.read_sql_query (sql,engine)
df_sql.head()
# Out:
# 2022-03-27 14:51:19,081 INFO sqlalchemy.engine.Engine
# select Name, avg(GP) as media
# from nba_details
# group by name
#
# 2022-03-27 14:51:19,083 INFO sqlalchemy.engine.Engine [raw sql] ()
#            Name  media
# 0    A.C. Green   82.0
# 1  A.J. English   70.0
# 2    A.J. Price   56.0
# 3  Aaron Brooks   51.0
# 4  Aaron Gordon   47.0

# %%
sql = """
select *
, 2022 as aux
, avg(GP) as media
from nba_details
where MIN > 0 and name like '%Morrison%'
group by name
"""

df_sql = pd.read_sql_query (sql,engine)
df_sql.head()
# Out:
# 2022-03-27 14:55:39,091 INFO sqlalchemy.engine.Engine
# select *
# , 2022 as aux
# , avg(GP) as media
# from nba_details
# where MIN > 0 and name like '%Morrison%'
# group by name
#
# 2022-03-27 14:55:39,093 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index           Name  GP   MIN   PTS  FGM   FGA   FG%  3P Made  3PA  ...  \
# 0    812  Adam Morrison  78  29.8  11.8  4.6  12.1  37.6      1.1  3.3  ...
# 1    179  Mike Morrison  36   4.3   2.0  0.6   1.9  33.8      0.1  0.2  ...
#
#    OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs   aux  media
# 0   0.7   2.3  2.9  2.1  0.4  0.1  1.7          0.0  2022   78.0
# 1   0.2   0.4  0.6  0.3  0.1  0.0  0.6          0.0  2022   36.0
#
# [2 rows x 24 columns]

# %%
sql = """
select *
, length(name) as n_elementos
, substr(name,5, length(name)) as n_5
from nba_details
"""

df_sql = pd.read_sql_query (sql,engine)
df_sql.head()
# Out:
# 2022-03-27 14:58:56,527 INFO sqlalchemy.engine.Engine
# select *
# , length(name) as n_elementos
# , substr(name,5, length(name)) as n_5
# from nba_details
#
# 2022-03-27 14:58:56,529 INFO sqlalchemy.engine.Engine [raw sql] ()
#    index             Name  GP   MIN  PTS  FGM  FGA   FG%  3P Made  3PA  ...  \
# 0      0   Brandon Ingram  36  27.4  7.4  2.6  7.6  34.7      0.5  2.1  ...
# 1      1  Andrew Harrison  35  26.9  7.2  2.0  6.7  29.6      0.7  2.8  ...
# 2      2   JaKarr Sampson  74  15.3  5.2  2.0  4.7  42.2      0.4  1.7  ...
# 3      3      Malik Sealy  58  11.6  5.7  2.3  5.5  42.6      0.1  0.5  ...
# 4      4      Matt Geiger  48  11.5  4.5  1.6  3.0  52.4      0.0  0.1  ...
#
#    OREB  DREB  REB  AST  STL  BLK  TOV  TARGET_5Yrs  n_elementos          n_5
# 0   0.7   3.4  4.1  1.9  0.4  0.4  1.3          0.0           14   don Ingram
# 1   0.5   2.0  2.4  3.7  1.1  0.5  1.6          0.0           15  ew Harrison
# ...
